# %%
# Scrapiing fake and real news data from a website (politifact.com)

# %%
# libraries
from bs4 import BeautifulSoup
import pandas as pd
import requests
import urllib.request
import time

# %%
# lists to store the scraped data
authors = []
dates = []
statements = []
sources = []
targets = []

# %%
# function to scrape the website
def scrape_website(page_number):
    page_num = str(page_number)
    URL = 'https://www.politifact.com/factchecks/list/?page=' + page_num
    webpage = requests.get(URL)
    soup = BeautifulSoup(webpage.text, 'html.parser')
    
    # location of the info
    statement_footer = soup.find_all('footer', 
                            attrs = {'class':'m-statement__footer'}) # location of the author
    statement_quote = soup.find_all('div',
                            attrs = {'class':'m-statement__quote'}) # location of the statement
    statement_meta = soup.find_all('div', 
                            attrs = {'class':'m-statement__meta'}) # location of the source
    target = soup.find_all('div',
                            attrs = {'class':'m-statement__meter'}) # location of the target (score)
    
    for i in statement_footer:
        link1 = i.text.strip()
        name_and_date = link1.split()
        first_name = name_and_date[1]
        last_name = name_and_date[2]
        full_name = first_name + ' ' + last_name
        month = name_and_date[4]
        day = name_and_date[5]
        year = name_and_date[6]
        date = month + ' ' + day + ' ' + year
        dates.append(date)
        authors.append(full_name)
        
    for i in statement_quote:
        link2 = i.find_all('a')
        statement_text = link2[0].text.strip()
        statements.append(statement_text)
        
    for i in statement_meta:
        link3 = i.find_all('a')
        source_text = link3[0].text.strip()
        sources.append(source_text)
        
    for i in target:
        link4 = i.find('div', attrs = {'class':'c-image'}).find('img').get('alt')
        targets.append(link4)

# %%
# n-1 webpage(s) loop
n = 2 # for 1 page
for i in range(1,n):
    scrape_website(i)

# %%
# check array length
len(dates) == len(authors) == len(statements) == len(targets) == len(sources)
# Out:
# True

# %%
# dataframe
data = pd.DataFrame(columns = ['author','statement','source','date','target'])
data['author'] = authors
data['statement'] = statements
data['source'] = sources
data['date'] = dates
data['target'] = targets

# data
data
# Out:
#                  author                                          statement  \
# 0         Tom Kertscher  “If I don’t take the vaccine, I’m at risk for ...
# 1         Jon Greenberg  Calls COVID-19 vaccine a “non-FDA-approved exp...
# 2     Gabrielle Settles  A map shows “all the cargo ships backed up by ...
# 3               Noah Y.  Says H.R. 1 gives immigrants illegally in the ...
# 4           Andy Nguyen  “From Europe: 3,964 people have died from adve...
# 5        Louis Jacobson  If the voting bill H.R. 1 is passed, “absentee...
# 6           Amy Sherman  U.S. Rep. Matt Gaetz was the lone vote in the ...
# 7        Madison Czopek  Video says COVID-19 vaccines are “weapons of m...
# 8   Michael Majchrowicz       Image of expansive pit shows a lithium mine.
# 9    Samantha Putterman  Says Ben Shapiro said on Twitter that his “red...
# 10        Tom Kertscher  “Joe Biden puts pro-life groups on domestic ex...
# 11          Amy Sherman  Georgia’s new voting law “makes it a JAIL-TIME...
# 12        Jon Greenberg  Says Deborah Birx “traveled a great distance t...
# 13        Tom Kertscher  “Minority farmers get big bonus, white ones ge...
# 14   Samantha Putterman  The ship that was stuck in the Suez Canal was ...
# 15        Bill McCarthy  Says Rachel Levine was Time magazine's "Woman ...
# 16              Noah Y.  Nostradamus predicted that a “feeble man” woul...
# 17       Madison Czopek  Says Sen. Cory Booker wants to require a feder...
# 18           Eric Litke  Judge Jeff Davis "spent years defending a conv...
# 19         Warren Fiske  “There is no discernible difference between th...
# 20        Tom Kertscher  “Less than 500 people a year killed by all rif...
# 21        Tom Kertscher  Says the suspected Boulder mass shooter is a M...
# 22        Bill McCarthy  “Toxicology report was made public by the MN p...
# 23    Gabrielle Settles  Says Jimmy Kimmel, Jimmy Fallon and Stephen Co...
# 24   Samantha Putterman  Says Google Earth blocked people from seeing t...
# 25      Miriam Valverde  “We spent billions on a border wall and quit w...
# 26          Amy Sherman  A Georgia law has not “criminalized giving peo...
# 27       Louis Jacobson  "There are 43 states that have now passed vote...
# 28          Paul Specht  "Joe Biden forced the U.S. Attorney for the Ea...
# 29              Noah Y.  Nike and Lil Nas X are launching “demonic shoe...
#
#              source            date       target
# 0    Facebook posts  March 31, 2021        false
# 1   Instagram posts  March 31, 2021  barely-true
# 2    Facebook posts  March 31, 2021        false
# 3   Instagram posts     • March 31,        false
# 4          Bloggers  March 31, 2021        false
# 5    Facebook posts  March 31, 2021        false
# 6    Facebook posts  March 31, 2021         true
# 7    Facebook posts  March 31, 2021   pants-fire
# 8       Viral image  March 31, 2021        false
# 9    Facebook posts  March 31, 2021   pants-fire
# 10   Facebook posts  March 31, 2021  barely-true
# 11   Facebook posts  March 30, 2021        false
# 12     Donald Trump  March 30, 2021    half-true
# 13   Facebook posts  March 30, 2021    half-true
# 14  Instagram posts  March 30, 2021        false
# 15   Facebook posts  March 30, 2021        false
# 16   Facebook posts     • March 30,   pants-fire
# 17      Viral image  March 30, 2021  mostly-true
# 18   Shelley Grogan  March 30, 2021    half-true
# 19      Pete Snyder  March 30, 2021        false
# 20   Facebook posts  March 30, 2021  barely-true
# 21   Facebook posts  March 30, 2021  barely-true
# 22   Facebook posts  March 30, 2021        false
# 23   Facebook posts  March 30, 2021        false
# 24   Facebook posts  March 29, 2021        false
# 25   Facebook posts  March 29, 2021  barely-true
# 26      Josh Holmes  March 29, 2021  barely-true
# 27    James Clyburn  March 29, 2021        false
# 28           Tweets  March 29, 2021  barely-true
# 29   Facebook posts     • March 29,    half-true

# %%
# function to get a binary number from the target
# info must be fully true
def getBinaryNumTarget(text):
    if text == 'true':
        return 1
    else:
        return 0

# %%
# function to get a binary label true(REAL) or false(FAKE) from the target
# info must be fully true
def getBinaryTarget(text):
    if text == 'true':
        return 'REAL'
    else:
        return 'FAKE'

# %%
# two new columns on the df
data['BinaryTarget'] = data['target'].apply(getBinaryTarget)
data['BinaryNumTarget'] = data['target'].apply(getBinaryNumTarget)

# %%
data
# Out:
#                  author                                          statement  \
# 0         Tom Kertscher  “If I don’t take the vaccine, I’m at risk for ...
# 1         Jon Greenberg  Calls COVID-19 vaccine a “non-FDA-approved exp...
# 2     Gabrielle Settles  A map shows “all the cargo ships backed up by ...
# 3               Noah Y.  Says H.R. 1 gives immigrants illegally in the ...
# 4           Andy Nguyen  “From Europe: 3,964 people have died from adve...
# 5        Louis Jacobson  If the voting bill H.R. 1 is passed, “absentee...
# 6           Amy Sherman  U.S. Rep. Matt Gaetz was the lone vote in the ...
# 7        Madison Czopek  Video says COVID-19 vaccines are “weapons of m...
# 8   Michael Majchrowicz       Image of expansive pit shows a lithium mine.
# 9    Samantha Putterman  Says Ben Shapiro said on Twitter that his “red...
